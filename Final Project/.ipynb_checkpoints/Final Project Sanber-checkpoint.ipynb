# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#           id  Umur                  Kelas Pekerja  Berat Akhir Pendidikan  \
# 0          0    21                     Wiraswasta       242912        SMA
# 1          1    49                     Wiraswasta       140782       10th
# 2          2    44                     Wiraswasta       120057         D3
# 3          3    24                     Wiraswasta       194630    Sarjana
# 4          4    33                     Wiraswasta       219619     Master
# ...      ...   ...                            ...          ...        ...
# 35989  35989    47  Pekerja Bebas Bukan Perusahan       148169        SMA
# 35990  35990    69       Pekerja Bebas Perusahaan       264722         D3
# 35991  35991    24  Pekerja Bebas Bukan Perusahan        31606    Sarjana
# 35992  35992    47                     Wiraswasta       197836        SMA
# 35993  35993    45                     Wiraswasta       243743    Sarjana
#
#        Jmlh Tahun Pendidikan     Status Perkawinan              Pekerjaan  \
# ...

# %%
train = df.copy()

# %%
train
# Out:
#           id  Umur                  Kelas Pekerja  Berat Akhir Pendidikan  \
# 0          0    21                     Wiraswasta       242912        SMA
# 1          1    49                     Wiraswasta       140782       10th
# 2          2    44                     Wiraswasta       120057         D3
# 3          3    24                     Wiraswasta       194630    Sarjana
# 4          4    33                     Wiraswasta       219619     Master
# ...      ...   ...                            ...          ...        ...
# 35989  35989    47  Pekerja Bebas Bukan Perusahan       148169        SMA
# 35990  35990    69       Pekerja Bebas Perusahaan       264722         D3
# 35991  35991    24  Pekerja Bebas Bukan Perusahan        31606    Sarjana
# 35992  35992    47                     Wiraswasta       197836        SMA
# 35993  35993    45                     Wiraswasta       243743    Sarjana
#
#        Jmlh Tahun Pendidikan     Status Perkawinan              Pekerjaan  \
# ...

# %%
miss_kp = {
    '?':'Wiraswasta'
}

miss_p = {
    '?':'Spesialis'
}


pendidikan = {
    'SD': 1,
    '1st-4th': 2,
    '5th-6th': 3,
    '7th-8th': 4,
    '9th': 5,
    '10th': 6,
    '11th': 7,
    '12th': 8,
    'SMA': 9,
    'Pendidikan Tinggi': 10,
    'D4': 11,
    'D3': 12,
    'Sarjana': 13,
    'Master': 14,
    'Sekolah Professional': 15,
    'Doktor': 16
}

jk = {
    'Perempuan': 0,
    'Laki2': 1
}

gaji = {
    '<=7jt': 0, 
    '>7jt': 1
}

# %%
train['Pendidikan'] = train['Pendidikan'].replace(pendidikan)
train['Jenis Kelamin'] = train['Jenis Kelamin'].replace(jk)
train['Kelas Pekerja'] = train['Kelas Pekerja'].replace(miss_kp)
train['Pekerjaan'] = train['Pekerjaan'].replace(miss_p)
train['Gaji'] = train['Gaji'].replace(gaji)

# %%
trainc = train.copy()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

#Using Pearson Correlation
plt.figure(figsize=(12,10))
trainc['Kelas Pekerja']=trainc['Kelas Pekerja'].astype('category').cat.codes
trainc['Pekerjaan']=trainc['Pekerjaan'].astype('category').cat.codes
trainc['Status Perkawinan']=trainc['Status Perkawinan'].astype('category').cat.codes
cor = trainc.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
sorting = trainc.corrwith(train['Gaji'])
sorting.sort_values()
# Out:
# Kelas Pekerja           -0.121076
# Pekerjaan               -0.035549
# Berat Akhir             -0.004272
# id                       0.005335
# Kerugian Capital         0.144413
# Jenis Kelamin            0.210142
# Keuntungan Kapital       0.223689
# Jam per Minggu           0.224214
# Umur                     0.232528
# Pendidikan               0.332439
# Jmlh Tahun Pendidikan    0.332439
# Status Perkawinan        0.405563
# Gaji                     1.000000
# dtype: float64

# %%
train_filtered = train[['Umur', 'Pendidikan', 'Status Perkawinan', 'Jam per Minggu', 'Pekerjaan', 'Keuntungan Kapital', 'Gaji']]
train_filtered
# Out:
#        Umur  Pendidikan     Status Perkawinan  Jam per Minggu  \
# 0        21           9  Belum Pernah Menikah            35.0
# 1        49           6                 Cerai            40.0
# 2        44          12               Menikah            45.0
# 3        24          13  Belum Pernah Menikah            35.0
# 4        33          14               Menikah            40.0
# ...     ...         ...                   ...             ...
# 35989    47           9               Menikah            40.0
# 35990    69          12               Menikah            40.0
# 35991    24          13               Menikah            20.0
# 35992    47           9               Menikah            45.0
# 35993    45          13               Menikah            60.0
#
#                    Pekerjaan  Keuntungan Kapital  Gaji
# 0             Servis Lainnya                 0.0     0
# 1      Ekesekutif Managerial                 0.0     0
# ...

# %%
# train_filtered = pd.get_dummies(train_filtered, columns=['Kelas Pekerja'])
train_filtered = pd.get_dummies(train_filtered, columns=['Pekerjaan'])
train_filtered = pd.get_dummies(train_filtered, columns=['Status Perkawinan'])
train_filtered
# Out:
#        Umur  Pendidikan  Jam per Minggu  Keuntungan Kapital  Gaji  \
# 0        21           9            35.0                 0.0     0
# 1        49           6            40.0                 0.0     0
# 2        44          12            45.0          61404000.0     1
# 3        24          13            35.0                 0.0     0
# 4        33          14            40.0         210336000.0     1
# ...     ...         ...             ...                 ...   ...
# 35989    47           9            40.0                 0.0     0
# 35990    69          12            40.0                 0.0     1
# 35991    24          13            20.0                 0.0     1
# 35992    47           9            45.0                 0.0     0
# 35993    45          13            60.0                 0.0     1
#
#        Pekerjaan_Asisten Rumah Tangga  Pekerjaan_Ekesekutif Managerial  \
# 0                                   0                                0
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
import numpy as np

# %%
X = train_filtered.drop(columns=['Gaji'])
y = train_filtered['Gaji']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=21, stratify=y)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler = StandardScaler()
ds_train = scaler.fit_transform(X_train)
ds_test = scaler.transform(X_test)

# %%
cols = X_train.columns
X_train = pd.DataFrame(ds_train, columns=cols)
X_test = pd.DataFrame(ds_test, columns=cols)

# %%
model = KNeighborsClassifier()
param_grid = {
    'n_neighbors': np.arange(1,20),
    'weights':['uniform','distance']
}

gscv = GridSearchCV(model, param_grid, scoring='roc_auc', cv=3, verbose=10)
gscv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 38 candidates, totalling 114 fits
# [CV] n_neighbors=1, weights=uniform ..................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ...... n_neighbors=1, weights=uniform, score=0.719, total=  17.5s
# [CV] n_neighbors=1, weights=uniform ..................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   17.4s remaining:    0.0s
# [CV] ...... n_neighbors=1, weights=uniform, score=0.721, total=  15.1s
# [CV] n_neighbors=1, weights=uniform ..................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   32.5s remaining:    0.0s
# [CV] ...... n_neighbors=1, weights=uniform, score=0.727, total=  14.8s
# [CV] n_neighbors=1, weights=distance .................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   47.3s remaining:    0.0s
# [CV] ..... n_neighbors=1, weights=distance, score=0.719, total=  14.8s
# ...

# %%
print(gscv.best_params_)
print(gscv.best_score_)
# Out:
# {'n_neighbors': 19, 'weights': 'uniform'}
# 0.8840639711161172

# %%
model = KNeighborsClassifier(n_neighbors=19, weights='uniform')
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=19, p=2,
#                      weights='uniform')

# %%
y_predict = model.predict(X_test)

# %%
from sklearn.metrics import roc_auc_score

print(roc_auc_score(y_test, y_predict))
# Out:
# 0.749224360438762

# %%
df2 = pd.read_csv('test.csv')

# %%
df2
# Out:
#          id  Umur                  Kelas Pekerja  Berat Akhir  \
# 0     35994    30               Pemerintah Lokal        99761
# 1     35995    28                     Wiraswasta       202206
# 2     35996    34            Pemerintah Provinsi       199934
# 3     35997    51                     Wiraswasta       373448
# 4     35998    20                              ?       144685
# ...     ...   ...                            ...          ...
# 9594  45588    58              Pemerintah Negara       159021
# 9595  45589    45  Pekerja Bebas Bukan Perusahan       144086
# 9596  45590    20                     Wiraswasta       238685
# 9597  45591    41               Pemerintah Lokal       249039
# 9598  45592    34  Pekerja Bebas Bukan Perusahan        24961
#
#              Pendidikan  Jmlh Tahun Pendidikan     Status Perkawinan  \
# 0                    D4                     11                 Cerai
# 1                   SMA                      9               Menikah
# ...

# %%
test = df2.copy()

# %%
test
# Out:
#          id  Umur                  Kelas Pekerja  Berat Akhir  \
# 0     35994    30               Pemerintah Lokal        99761
# 1     35995    28                     Wiraswasta       202206
# 2     35996    34            Pemerintah Provinsi       199934
# 3     35997    51                     Wiraswasta       373448
# 4     35998    20                              ?       144685
# ...     ...   ...                            ...          ...
# 9594  45588    58              Pemerintah Negara       159021
# 9595  45589    45  Pekerja Bebas Bukan Perusahan       144086
# 9596  45590    20                     Wiraswasta       238685
# 9597  45591    41               Pemerintah Lokal       249039
# 9598  45592    34  Pekerja Bebas Bukan Perusahan        24961
#
#              Pendidikan  Jmlh Tahun Pendidikan     Status Perkawinan  \
# 0                    D4                     11                 Cerai
# 1                   SMA                      9               Menikah
# ...

# %%
test['Pendidikan'] = test['Pendidikan'].replace(pendidikan)
test['Jenis Kelamin'] = test['Jenis Kelamin'].replace(jk)
test['Kelas Pekerja'] = test['Kelas Pekerja'].replace(miss_kp)
test['Pekerjaan'] = test['Pekerjaan'].replace(miss_p)

# %%
test_filtered = test[['Umur', 'Pendidikan', 'Status Perkawinan', 'Jam per Minggu', 'Pekerjaan']]
test_filtered
# Out:
#       Umur  Pendidikan     Status Perkawinan  Jam per Minggu  \
# 0       30          11                 Cerai            40.0
# 1       28           9               Menikah            50.0
# 2       34          10               Menikah            40.0
# 3       51          10               Menikah            40.0
# 4       20          10  Belum Pernah Menikah            40.0
# ...    ...         ...                   ...             ...
# 9594    58           5               Menikah            40.0
# 9595    45           7               Menikah            50.0
# 9596    20          10  Belum Pernah Menikah            32.0
# 9597    41           9              Berpisah            40.0
# 9598    34           9               Menikah            80.0
#
#                   Pekerjaan
# 0              Pemuka Agama
# 1            Mesin Inspeksi
# 2              Pemuka Agama
# 3     Ekesekutif Managerial
# 4                 Spesialis
# ...                     ...
# ...

# %%
# test_filtered = pd.get_dummies(test_filtered, columns=['Kelas Pekerja'])
test_filtered = pd.get_dummies(test_filtered, columns=['Pekerjaan'])
test_filtered = pd.get_dummies(test_filtered, columns=['Status Perkawinan'])
test_filtered
# Out:
#       Umur  Pendidikan  Jam per Minggu  Pekerjaan_Asisten Rumah Tangga  \
# 0       30          11            40.0                               0
# 1       28           9            50.0                               0
# 2       34          10            40.0                               0
# 3       51          10            40.0                               0
# 4       20          10            40.0                               0
# ...    ...         ...             ...                             ...
# 9594    58           5            40.0                               0
# 9595    45           7            50.0                               0
# 9596    20          10            32.0                               0
# 9597    41           9            40.0                               0
# 9598    34           9            80.0                               0
#
#       Pekerjaan_Ekesekutif Managerial  Pekerjaan_Mesin Inspeksi  \
# ...

# %%
X_test = test_filtered.copy()
X_test
# Out:
#       Umur  Pendidikan  Jam per Minggu  Pekerjaan_Asisten Rumah Tangga  \
# 0       30          11            40.0                               0
# 1       28           9            50.0                               0
# 2       34          10            40.0                               0
# 3       51          10            40.0                               0
# 4       20          10            40.0                               0
# ...    ...         ...             ...                             ...
# 9594    58           5            40.0                               0
# 9595    45           7            50.0                               0
# 9596    20          10            32.0                               0
# 9597    41           9            40.0                               0
# 9598    34           9            80.0                               0
#
#       Pekerjaan_Ekesekutif Managerial  Pekerjaan_Mesin Inspeksi  \
# ...

# %%
ds_test = scaler.transform(X_test)
X_test = pd.DataFrame(ds_test, columns=cols)

# %%
y_predict = model.predict(X_test)

# %%
y_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
submission = pd.DataFrame({
    'id':test['id'],
    'Gaji':y_predict
})

# %%
submission.to_csv(r'C:\Users\Hanif\Anaconda Projek\SanberCode\Final Project\submission2.csv', index=False)

# %%
sample = pd.read_csv('submission2.csv')
sample.loc[sample['Gaji'] == 0]
# Out:
#          id  Gaji
# 0     35994     0
# 1     35995     0
# 2     35996     0
# 4     35998     0
# 6     36000     0
# ...     ...   ...
# 9594  45588     0
# 9595  45589     0
# 9596  45590     0
# 9597  45591     0
# 9598  45592     0
#
# [7668 rows x 2 columns]
